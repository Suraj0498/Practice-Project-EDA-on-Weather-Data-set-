# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
fifa = pd.read_csv(r'C:\Users\Admin\Downloads\players_20.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, CF, ST
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 2          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 3          E. Hazard                          Eden Hazard           LW, CF
# 4       K. De Bruyne                      Kevin De Bruyne          CAM, CM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# player_positions
# overall
# potential
# value_eur
# wage_eur
# age
# dob
# height_cm
# weight_kg
# club_team_id
# club_name
# league_name
# league_level
# club_position
# club_jersey_number
# club_loaned_from
# club_joined
# club_contract_valid_until
# nationality_id
# nationality_name
# nation_team_id
# nation_position
# nation_jersey_number
# preferred_foot
# weak_foot
# skill_moves
# international_reputation
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# player_traits
# pace
# shooting
# passing
# dribbling
# defending
# physic
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# ...

# %%
fifa.shape
# Out:
# (18483, 110)

# %%
fifa['nationality_name'].value_counts()
# Out:
# England        1670
# Germany        1218
# Spain          1045
# France         1004
# Argentina       886
#                ...
# Puerto Rico       1
# Eritrea           1
# Bahrain           1
# Chad              1
# Indonesia         1
# Name: nationality_name, Length: 162, dtype: int64

# %%
fifa['nationality_name'].value_counts()[0:10]
# Out:
# England        1670
# Germany        1218
# Spain          1045
# France         1004
# Argentina       886
# Brazil          827
# Italy           732
# Colombia        612
# Japan           479
# Netherlands     416
# Name: nationality_name, dtype: int64

# %%
fifa['nationality_name'].value_counts()[0:5]
# Out:
# England      1670
# Germany      1218
# Spain        1045
# France       1004
# Argentina     886
# Name: nationality_name, dtype: int64

# %%
fifa['nationality_name'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
plt.figure(figsize=(10,10))
plt.bar(list(fifa['nationality_name'].value_counts()[0:5].keys()),list(fifa['nationality_name'].value_counts()[0:5]),color='red')
plt.show()

# %%
salary=fifa[['short_name','wage_eur','value_eur']]

# %%
salary.head(2)
# Out:
#           short_name  wage_eur   value_eur
# 0           L. Messi  560000.0  95500000.0
# 1  Cristiano Ronaldo  410000.0  58500000.0

# %%
salary=salary.sort_values(by=['wage_eur'], ascending=False)

# %%
salary.head()
# Out:
#            short_name  wage_eur   value_eur
# 0            L. Messi  560000.0  95500000.0
# 3           E. Hazard  470000.0  90000000.0
# 1   Cristiano Ronaldo  410000.0  58500000.0
# 4        K. De Bruyne  370000.0  90000000.0
# 17       A. Griezmann  370000.0  69000000.0

# %%
plt.figure(figsize=(10,7))
plt.bar(list(salary['short_name'])[0:5], list(salary['wage_eur'])[0:5], color=['red','yellow','blue','green','brown','black'])
plt.show()

# %%
germany=fifa[fifa['nationality_name']=='Germany']

# %%
germany.head(2)
# Out:
#     sofifa_id                                         player_url  \
# 7      192448  https://sofifa.com/player/192448/marc-andre-te...
# 25     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#        short_name              long_name player_positions  overall  potential  \
# 7   M. ter Stegen  Marc-André ter Stegen               GK       90         93
# 25       M. Neuer     Manuel Peter Neuer               GK       88         88
#
#      value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# 7   67500000.0  250000.0   27  ...  33+3  33+3  33+3  31+3  88+3
# 25  32000000.0  155000.0   33  ...  34+3  34+3  34+3  34+3  86+2
#
#                                       player_face_url  \
# 7   https://cdn.sofifa.net/players/192/448/20_120.png
# 25  https://cdn.sofifa.net/players/167/495/20_120.png
#
#                               club_logo_url  \
# 7   https://cdn.sofifa.net/teams/241/60.png
# 25   https://cdn.sofifa.net/teams/21/60.png
#
# ...

# %%
germany.sort_values(by=['height_cm'], ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 8550      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1094      200212  https://sofifa.com/player/200212/michael-esser...
# 1411      199833  https://sofifa.com/player/199833/lars-unnersta...
# 16208     240218  https://sofifa.com/player/240218/alexander-wei...
# 13736     239746  https://sofifa.com/player/239746/lukas-watkowi...
# ...          ...                                                ...
# 5810      189209  https://sofifa.com/player/189209/sascha-bigalk...
# 17999     239129  https://sofifa.com/player/239129/jakob-gesien/...
# 12191     250936  https://sofifa.com/player/250936/seref-ozcan/2...
# 16375     247284  https://sofifa.com/player/247284/patrick-finge...
# 12181     248879  https://sofifa.com/player/248879/kevin-holzwei...
#
#           short_name            long_name player_positions  overall  \
# 8550       A. Seydel         Aaron Seydel           ST, LM       67
# ...

# %%
germany.sort_values(by=['weight_kg'], ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 1411      199833  https://sofifa.com/player/199833/lars-unnersta...
# 13736     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 443       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1094      200212  https://sofifa.com/player/200212/michael-esser...
# 13775     241388  https://sofifa.com/player/241388/dennis-smarsc...
# ...          ...                                                ...
# 5810      189209  https://sofifa.com/player/189209/sascha-bigalk...
# 12181     248879  https://sofifa.com/player/248879/kevin-holzwei...
# 14090     252559  https://sofifa.com/player/252559/volkan-egri/2...
# 17999     239129  https://sofifa.com/player/239129/jakob-gesien/...
# 18038     244094  https://sofifa.com/player/244094/leonard-langh...
#
#           short_name                long_name player_positions  overall  \
# 1411   L. Unnerstall          Lars Unnerstall               GK       76
# ...

# %%
germany[['short_name','wage_eur']].sort_values(by=['wage_eur'], ascending=False)
# Out:
#           short_name  wage_eur
# 30          T. Kroos  330000.0
# 7      M. ter Stegen  250000.0
# 71           L. Sané  195000.0
# 126      İ. Gündoğan  180000.0
# 31           M. Reus  165000.0
# ...              ...       ...
# 13018      M. Hiller     500.0
# 15934        Y. Osée     500.0
# 15929       P. Hoppe     500.0
# 13021   E. Bekiroglu     500.0
# 18391     M. Harsman     500.0
#
# [1218 rows x 2 columns]
